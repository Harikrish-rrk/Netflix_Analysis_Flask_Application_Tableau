# %%
import pandas as pd
import numpy as np
m=pd.read_csv('Best Movies Netflix.csv')
#find no of na 
print("__________________")
m["type"]=["Movies" for i in range(len(m.index))]
# m["NUMBER_OF_SEASONS"]=["none" for i in range(len(m.index))]
# df=m
m.insert(loc = len(m.columns)-3,column ="NUMBER_OF_SEASONS",value = [0 for i in range(len(m.index))])
movies_title=list(m.columns)
print(m.isna().sum())
# Out:
# __________________
# index                0
# TITLE                0
# RELEASE_YEAR         0
# SCORE                0
# NUMBER_OF_VOTES      0
# DURATION             0
# NUMBER_OF_SEASONS    0
# MAIN_GENRE           0
# MAIN_PRODUCTION      0
# type                 0
# dtype: int64

# %%
m.head()
# Out:
#    index                                     TITLE  RELEASE_YEAR  SCORE  \
# 0      0  David Attenborough: A Life on Our Planet          2020    9.0
# 1      1                                 Inception          2010    8.8
# 2      2                              Forrest Gump          1994    8.8
# 3      3                                Anbe Sivam          2003    8.7
# 4      4                        Bo Burnham: Inside          2021    8.7
#
#    NUMBER_OF_VOTES  DURATION  NUMBER_OF_SEASONS   MAIN_GENRE MAIN_PRODUCTION  \
# 0            31180        83                  0  documentary              GB
# 1          2268288       148                  0        scifi              GB
# 2          1994599       142                  0        drama              US
# 3            20595       160                  0       comedy              IN
# 4            44074        87                  0       comedy              US
#
#      type
# 0  Movies
# 1  Movies
# 2  Movies
# 3  Movies
# 4  Movies

# %%
m.tail()
# Out:
#      index                TITLE  RELEASE_YEAR  SCORE  NUMBER_OF_VOTES  \
# 382    382             The Trip          2021    6.9            19706
# 383    383             The Dirt          2019    6.9            47603
# 384    384              Top Gun          1986    6.9           329656
# 385    385          Radhe Shyam          2022    6.9            21328
# 386    386  Sorry to Bother You          2018    6.9            75653
#
#      DURATION  NUMBER_OF_SEASONS MAIN_GENRE MAIN_PRODUCTION    type
# 382       113                  0     comedy              NO  Movies
# 383       108                  0      drama              US  Movies
# 384       110                  0      drama              US  Movies
# 385       138                  0    romance              IN  Movies
# 386       111                  0    fantasy              US  Movies

# %%
import pandas as pd
import numpy as np
x=pd.read_csv('Best Shows Netflix.csv')
#find no of na 
print("__________________")
x["type"]=["Series" for i in range(len(x.index))]
series_title=list(x.columns)
print(x.isna().sum())
# Out:
# __________________
# index                0
# TITLE                0
# RELEASE_YEAR         0
# SCORE                0
# NUMBER_OF_VOTES      0
# DURATION             0
# NUMBER_OF_SEASONS    0
# MAIN_GENRE           0
# MAIN_PRODUCTION      0
# type                 0
# dtype: int64

# %%
x.head()
# Out:
#    index                       TITLE  RELEASE_YEAR  SCORE  NUMBER_OF_VOTES  \
# 0      0                Breaking Bad          2008    9.5          1727694
# 1      1  Avatar: The Last Airbender          2005    9.3           297336
# 2      2                  Our Planet          2019    9.3            41386
# 3      3                Kota Factory          2019    9.3            66985
# 4      4              The Last Dance          2020    9.1           108321
#
#    DURATION  NUMBER_OF_SEASONS   MAIN_GENRE MAIN_PRODUCTION    type
# 0        48                  5        drama              US  Series
# 1        24                  3        scifi              US  Series
# 2        50                  1  documentary              GB  Series
# 3        42                  2        drama              IN  Series
# 4        50                  1  documentary              US  Series

# %%
x.tail()
# Out:
#      index                    TITLE  RELEASE_YEAR  SCORE  NUMBER_OF_VOTES  \
# 241    241              Evil Genius          2018    7.5            27516
# 242    242           13 Reasons Why          2017    7.5           282373
# 243    243                    Lupin          2021    7.5           100575
# 244    244       All of Us Are Dead          2022    7.5            41393
# 245    245  I Am Not Okay with This          2020    7.5            56459
#
#      DURATION  NUMBER_OF_SEASONS MAIN_GENRE MAIN_PRODUCTION    type
# 241        48                  1      crime              US  Series
# 242        58                  4      drama              US  Series
# 243        46                  3      crime              FR  Series
# 244        61                  1     action              KR  Series
# 245        21                  1     comedy              US  Series

# %%
if(movies_title==series_title):
    print("yes")
else:
    print("no")
print(movies_title)
print(series_title)
# Out:
# yes
# ['index', 'TITLE', 'RELEASE_YEAR', 'SCORE', 'NUMBER_OF_VOTES', 'DURATION', 'NUMBER_OF_SEASONS', 'MAIN_GENRE', 'MAIN_PRODUCTION', 'type']
# ['index', 'TITLE', 'RELEASE_YEAR', 'SCORE', 'NUMBER_OF_VOTES', 'DURATION', 'NUMBER_OF_SEASONS', 'MAIN_GENRE', 'MAIN_PRODUCTION', 'type']

# %%
import pandas as pd
print('Dataframes:')
display(m)
display(x)
# Out:
# Dataframes:
#      index                                     TITLE  RELEASE_YEAR  SCORE  \
# 0        0  David Attenborough: A Life on Our Planet          2020    9.0
# 1        1                                 Inception          2010    8.8
# 2        2                              Forrest Gump          1994    8.8
# 3        3                                Anbe Sivam          2003    8.7
# 4        4                        Bo Burnham: Inside          2021    8.7
# ..     ...                                       ...           ...    ...
# 382    382                                  The Trip          2021    6.9
# 383    383                                  The Dirt          2019    6.9
# 384    384                                   Top Gun          1986    6.9
# 385    385                               Radhe Shyam          2022    6.9
# 386    386                       Sorry to Bother You          2018    6.9
#
#      NUMBER_OF_VOTES  DURATION  NUMBER_OF_SEASONS   MAIN_GENRE  \
# ...

# %%
# merge two data frames
print('After merging:')
new_dataset=pd.concat([m, x], axis=0)
new_dataset.reset_index(inplace=True)
new_dataset.drop('index',axis=1,inplace=True)
new_dataset
# Out:
# After merging:
#      level_0                                     TITLE  RELEASE_YEAR  SCORE  \
# 0          0  David Attenborough: A Life on Our Planet          2020    9.0
# 1          1                                 Inception          2010    8.8
# 2          2                              Forrest Gump          1994    8.8
# 3          3                                Anbe Sivam          2003    8.7
# 4          4                        Bo Burnham: Inside          2021    8.7
# ..       ...                                       ...           ...    ...
# 628      241                               Evil Genius          2018    7.5
# 629      242                            13 Reasons Why          2017    7.5
# 630      243                                     Lupin          2021    7.5
# 631      244                        All of Us Are Dead          2022    7.5
# 632      245                   I Am Not Okay with This          2020    7.5
#
# ...

# %%
import pandas as pd
import re
# to resolve utf uploding error
def fn(df, column_name):
    df[column_name] = df[column_name].str.replace(r'[^A-Za-z0-9\s.\'\"\-?s!/@,:#:$%^&*()]', ' ')
    return df

fn(new_dataset,"TITLE")    
new_dataset.head(28)
# Out:
#     level_0                                        TITLE  RELEASE_YEAR  SCORE  \
# 0         0     David Attenborough: A Life on Our Planet          2020    9.0
# 1         1                                    Inception          2010    8.8
# 2         2                                 Forrest Gump          1994    8.8
# 3         3                                   Anbe Sivam          2003    8.7
# 4         4                           Bo Burnham: Inside          2021    8.7
# 5         5                          Saving Private Ryan          1998    8.6
# 6         6                             Django Unchained          2012    8.4
# 7         7                                       Dangal          2016    8.4
# 8         8                       Bo Burnham: Make Happy          2016    8.4
# 9         9                        Louis C.K.: Hilarious          2010    8.4
# 10       10              Dave Chappelle: Sticks & Stones          2019    8.4
# ...

# %%
def check_non_alphanumeric(df, column_name):
    non_alphanumeric_rows = df[df[column_name].str.contains(r'[^A-Za-z0-9]', na=False)]
    for index, value in non_alphanumeric_rows[column_name].items():
        print(f"Index: {index}, Value: {value}")
check_non_alphanumeric(new_dataset,"TITLE")
# Out:
# Index: 0, Value: David Attenborough: A Life on Our Planet
# Index: 2, Value: Forrest Gump
# Index: 3, Value: Anbe Sivam
# Index: 4, Value: Bo Burnham: Inside
# Index: 5, Value: Saving Private Ryan
# Index: 6, Value: Django Unchained
# Index: 8, Value: Bo Burnham: Make Happy
# Index: 9, Value: Louis C.K.: Hilarious
# Index: 10, Value: Dave Chappelle: Sticks & Stones
# Index: 11, Value: 3 Idiots
# Index: 12, Value: Black Friday
# Index: 13, Value: Super Deluxe
# Index: 14, Value: Winter on Fire: Ukraine's Fight for Freedom
# Index: 15, Value: Once Upon a Time in America
# Index: 16, Value: Taxi Driver
# Index: 17, Value: Like Stars on Earth
# Index: 18, Value: Bo Burnham: What.
# Index: 19, Value: Full Metal Jacket
# Index: 23, Value: Paan Singh Tomar
# Index: 24, Value: Cowspiracy: The Sustainability Secret
# Index: 27, Value: Bāhubali 2: The Conclusion
# Index: 28, Value: Monty Python and the Holy Grail
# Index: 29, Value: Article 15
# Index: 30, Value: Miracle in Cell No. 7
# ...

# %%
translationTable = str.maketrans('éàèâôûçā', 'eaeaouca')
new_dataset["TITLE"] = new_dataset["TITLE"].apply(lambda x: x.translate(translationTable))

# %%
def check_non_alphanumeric(df, column_name):
    non_alphanumeric_rows = df[df[column_name].str.contains(r'[^A-Za-z0-9\s.\'\"\-?s!/@,#:$%^&*()]', na=False)]
    for index, value in non_alphanumeric_rows[column_name].items():
        print(f"Index: {index}, Value: {value}")
check_non_alphanumeric(new_dataset,"TITLE")

# %%
#dealing with tableau maps
import pandas as pd
country_mapping = {
    'AR': 'Argentina',
    'AU': 'Australia',
    'BE': 'Belgium',
    'BR': 'Brazil',
    'CA': 'Canada',
    'CD': 'Democratic Republic of the Congo',
    'CN': 'China',
    'DE': 'Germany',
    'DK': 'Denmark',
    'ES': 'Spain',
    'FI': 'Finland',
    'FR': 'France',
    'GB': 'United Kingdom',
    'HK': 'Hong Kong',
    'HU': 'Hungary',
    'ID': 'Indonesia',
    'IE': 'Ireland',
    'IL': 'Israel',
    'IN': 'India',
    'IT': 'Italy',
    'JP': 'Japan',
    'KR': 'South Korea',
    'MX': 'Mexico',
    'NL': 'Netherlands',
    'NO': 'Norway',
    'NZ': 'New Zealand',
    'PH': 'Philippines',
    'PL': 'Poland',
    'RU': 'Russia',
    'SE': 'Sweden',
    'SG': 'Singapore',
    'US': 'United States',
    'ZA': 'South Africa',
    'MX' : 'Mexico',
    'TW' : 'Taiwan',
    'TH' : 'Thailand',
    'TR' : 'Turkey',
    'GR' : 'Greece',
    'RO' : 'Romania',
    'MW': 'Malawi',
    'UA': 'Ukraine',
    'PS': 'Palestine',
    'LT': 'Lithuania',
    'KH': 'Cambodia',

    # Add more country code mappings as needed
}

# Replace country codes with full names
new_dataset['Country'] = new_dataset['MAIN_PRODUCTION'].replace(country_mapping)

# %%
#save to csv
new_dataset.drop('level_0',axis=1,inplace=True)
new_dataset.index.name='Index'
new_dataset.to_csv('netflix_cleaned.csv',index=True)
new_dataset
new_dataset["NUMBER_OF_SEASONS"].to_csv('nx.csv',index=True)
